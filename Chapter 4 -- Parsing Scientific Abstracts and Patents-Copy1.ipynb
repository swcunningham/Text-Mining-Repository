# %%
# This function reads column structured text
# Input: File handle
# Output: Dictionary 

def read_column_structured(f):
    
    corpus={}
    unique_id = 'UT'
    
    for index, line in enumerate(f):
        line = line.rstrip('\n')
        fields = line.split('\t')
            
        if (index == 0):
            headers = fields
            endindex = fields.index(unique_id)
        else:
            article_id = fields[endindex]
            pair = zip(headers,fields)
            record = dict(pair)
            corpus[article_id]=record
            record = {}
            
    return corpus

# %%
# This function reads row structured text
# Input: File handle
# Output: Dictionary 

def read_row_structured(f):
    
    record={}
    corpus={}

    end_of_record = 'ER'
    unique_id = 'UT'
    
    for line in f:
        line = line.rstrip()

        tag = line[0:2]
        content = line.lstrip(tag+" ")

        if (tag == "  "):
            tag = lasttag
        lasttag = tag
            
        if tag in record:
            record[tag]=record[tag]+"; "+content
        else:
            record[tag]= content
            
        if (tag == unique_id):
            article_id = content
            
        if (tag == end_of_record):
            corpus[article_id]=record
            record = {}
                     
    return corpus

# %%
import json
from os import walk


def parse_files(inputfd,outputfile,parsedir=True,fileformat="column"):
    """Parse files or directories. 

    Keyword arguments:
    parsedir -- Parse a directory, otherwise parse a file (default True)
    inputfd -- The file name or directory
    fileformat -- The file format. Supported formats include column (default) and row
    outputfile -- The desired output path
    
    """
    # initialization
    allpaths = []
    corpus = {}
    
    # Find all files in directory 
    if (parsedir == True):
        allfiles = []
        for (dirpath, dirnames, filenames) in walk(inputfd):
            allfiles.extend(filenames)
            break
        for file in allfiles:
            newpath = inputfd+"/"+file
            allpaths.append(newpath)
                
    else:
        allpaths=[inputfd]

    # Process each file 
    for inputfile in allpaths:
        print("Opening file ", inputfile)
       
        with open(inputfile, 'r', encoding = 'utf-16') as f:
            if (fileformat == "column"):
                newcorpus = read_column_structured(f)
            elif (fileformat == "row"):
                newcorpus = read_row_structured(f)
            else:
                print("Format not understood")
            corpus.update(newcorpus)
            print("The total number of records is now:",len(corpus))
            
    with open(outputfile, 'w') as g:
        json.dump(corpus,g)

# %%
# try parsing a full directory
inputdir = "Data/nano/articles/column"
outputfile = "Output/nano/nano_articles_column_JSON1.txt"

print("Trying a full directory")
parse_files(inputdir,outputfile)
print()

# try parsing a single file
inputdir = "Data/nano/articles/column/article_nano_column1.txt"
outputfile = "Output/nano/nano_articles_column_JSON2.txt"
parsdir = False

print("Trying a single file")
parse_files(inputdir,outputfile,parsdir)
print()

# try parsing a full directory of row formatted files
inputdir = "Data/nano/patents/row"
outputfile = "Output/nano/nano_patents_row_JSON1.txt"
parsdir = True
fileformat = "row"

print("Trying a full directory of row formatted files")
parse_files(inputdir,outputfile,parsdir,fileformat)
print()

# try parsing a single row formatted file 
inputdir = "Data/nano/patents/patent_nano_row1.txt"
outputfile = "Output/nano/nano_patents_row_JSON2.txt"
parsdir = False
fileformat = "row"

print("Trying a single row-formatted file")
parse_files(inputdir,outputfile,parsdir,fileformat)
print()
# Out:
# Trying a full directory
# Opening file  Data/nano/articles/column/article_nano_column1.txt
# Opening file  Data/nano/articles/column/article_nano_column2.txt
# Opening file  Data/nano/articles/column/article_nano_column3.txt
# Opening file  Data/nano/articles/column/article_nano_column4.txt
# Opening file  Data/nano/articles/column/article_nano_column5.txt
#
# Trying a single file
# Opening file  Data/nano/articles/column/article_nano_column1.txt
#
# Trying a full directory of row formatted files
# Opening file  Data/nano/patents/row/patent_nano_row1.txt
# Opening file  Data/nano/patents/row/patent_nano_row2.txt
# Opening file  Data/nano/patents/row/patent_nano_row3.txt
# Opening file  Data/nano/patents/row/patent_nano_row4.txt
# Opening file  Data/nano/patents/row/patent_nano_row5.txt
#
# Trying a single row-formatted file
# Opening file  Data/nano/patents/patent_nano_row1.txt

# %%
# try parsing a full directory
inputdir = "Data/nano/fullset"
outputfile = "Output/nano/full_nano_JSON.txt"

print("Trying a full directory")
parse_files(inputdir,outputfile)
print()
# Out:
# Trying a full directory
# Opening file  Data/nano/fullset/nano1.txt
# The total number of records is now: 500
# Opening file  Data/nano/fullset/nano10.txt
# The total number of records is now: 1000
# Opening file  Data/nano/fullset/nano11.txt
# The total number of records is now: 1500
# Opening file  Data/nano/fullset/nano12.txt
# The total number of records is now: 2000
# Opening file  Data/nano/fullset/nano13.txt
# The total number of records is now: 2500
# Opening file  Data/nano/fullset/nano14.txt
# The total number of records is now: 3000
# Opening file  Data/nano/fullset/nano15.txt
# The total number of records is now: 3500
# Opening file  Data/nano/fullset/nano16.txt
# The total number of records is now: 4000
# Opening file  Data/nano/fullset/nano17.txt
# The total number of records is now: 4500
# Opening file  Data/nano/fullset/nano18.txt
# The total number of records is now: 4946
# Opening file  Data/nano/fullset/nano19.txt
# The total number of records is now: 5446
# Opening file  Data/nano/fullset/nano2.txt
# The total number of records is now: 5946
# Opening file  Data/nano/fullset/nano20.txt
# The total number of records is now: 6446
# Opening file  Data/nano/fullset/nano21.txt
# The total number of records is now: 6946
# Opening file  Data/nano/fullset/nano22.txt
# The total number of records is now: 7446
# Opening file  Data/nano/fullset/nano23.txt
# The total number of records is now: 7946
# Opening file  Data/nano/fullset/nano24.txt
# The total number of records is now: 8000
# Opening file  Data/nano/fullset/nano25.txt
# The total number of records is now: 8446
# Opening file  Data/nano/fullset/nano26.txt
# The total number of records is now: 8946
# Opening file  Data/nano/fullset/nano27.txt
# The total number of records is now: 9000
# Opening file  Data/nano/fullset/nano28.txt
# The total number of records is now: 9500
# Opening file  Data/nano/fullset/nano29.txt
# The total number of records is now: 10000
# Opening file  Data/nano/fullset/nano3.txt
# The total number of records is now: 10500
# Opening file  Data/nano/fullset/nano30.txt
# The total number of records is now: 11000
# Opening file  Data/nano/fullset/nano31.txt
# The total number of records is now: 11500
# Opening file  Data/nano/fullset/nano32.txt
# The total number of records is now: 12000
# Opening file  Data/nano/fullset/nano33.txt
# The total number of records is now: 12500
# Opening file  Data/nano/fullset/nano34.txt
# The total number of records is now: 13000
# Opening file  Data/nano/fullset/nano35.txt
# The total number of records is now: 13500
# Opening file  Data/nano/fullset/nano36.txt
# The total number of records is now: 14000
# Opening file  Data/nano/fullset/nano37.txt
# The total number of records is now: 14500
# Opening file  Data/nano/fullset/nano38.txt
# The total number of records is now: 15000
# Opening file  Data/nano/fullset/nano39.txt
# The total number of records is now: 15500
# Opening file  Data/nano/fullset/nano4.txt
# The total number of records is now: 16000
# Opening file  Data/nano/fullset/nano40.txt
# The total number of records is now: 16500
# Opening file  Data/nano/fullset/nano41.txt
# The total number of records is now: 17000
# Opening file  Data/nano/fullset/nano42.txt
# The total number of records is now: 17500
# Opening file  Data/nano/fullset/nano43.txt
# The total number of records is now: 18000
# Opening file  Data/nano/fullset/nano44.txt
# The total number of records is now: 18500
# Opening file  Data/nano/fullset/nano45.txt
# The total number of records is now: 19000
# Opening file  Data/nano/fullset/nano46.txt
# The total number of records is now: 19500
# Opening file  Data/nano/fullset/nano47.txt
# The total number of records is now: 20000
# Opening file  Data/nano/fullset/nano48.txt
# The total number of records is now: 20500
# Opening file  Data/nano/fullset/nano49.txt
# The total number of records is now: 21000
# Opening file  Data/nano/fullset/nano5.txt
# The total number of records is now: 21500
# Opening file  Data/nano/fullset/nano50.txt
# The total number of records is now: 22000
# Opening file  Data/nano/fullset/nano51.txt
# The total number of records is now: 22500
# Opening file  Data/nano/fullset/nano52.txt
# The total number of records is now: 23000
# Opening file  Data/nano/fullset/nano53.txt
# The total number of records is now: 23500
# Opening file  Data/nano/fullset/nano54.txt
# The total number of records is now: 24000
# Opening file  Data/nano/fullset/nano55.txt
# The total number of records is now: 24500
# Opening file  Data/nano/fullset/nano56.txt
# The total number of records is now: 25000
# Opening file  Data/nano/fullset/nano57.txt
# The total number of records is now: 25070
# Opening file  Data/nano/fullset/nano58.txt
# The total number of records is now: 25070
# Opening file  Data/nano/fullset/nano59.txt
# The total number of records is now: 25070
# Opening file  Data/nano/fullset/nano6.txt
# The total number of records is now: 25570
# Opening file  Data/nano/fullset/nano60.txt
# The total number of records is now: 25570
# Opening file  Data/nano/fullset/nano7.txt
# The total number of records is now: 26070
# Opening file  Data/nano/fullset/nano8.txt
# The total number of records is now: 26570
# Opening file  Data/nano/fullset/nano9.txt
# The total number of records is now: 27070
# Opening file  Data/nano/fullset/nanoA.txt
# The total number of records is now: 27122
# Opening file  Data/nano/fullset/nanoB.txt
# The total number of records is now: 27122
# Opening file  Data/nano/fullset/nanoC.txt
# The total number of records is now: 27122

# %%
# try parsing a single file
inputdir = "Data/nano/fullset/nano1.txt"
outputfile = "Output/nano/nano_articles_column_JSON1.txt"
parsdir = False

print("Trying a single file")
parse_files(inputdir,outputfile,parsdir)
print()
# Out:
# Trying a single file
# Opening file  Data/nano/fullset/nano1.txt
# ['PT', 'AU', 'BA', 'BE', 'GP', 'AF', 'BF', 'CA', 'TI', 'SO', 'SE', 'BS', 'LA', 'DT', 'CT', 'CY', 'CL', 'SP', 'HO', 'DE', 'ID', 'AB', 'C1', 'RP', 'EM', 'RI', 'OI', 'FU', 'FX', 'CR', 'NR', 'TC', 'Z9', 'PU', 'PI', 'PA', 'SN', 'EI', 'BN', 'J9', 'JI', 'PD', 'PY', 'VL', 'IS', 'PN', 'SU', 'SI', 'MA', 'BP', 'EP', 'AR', 'DI', 'D2', 'PG', 'WC', 'SC', 'GA', 'UT', 'PM']
